# %% [markdown]
# Minimal notebook for life testing of random small code parts.

# %%
# %load_ext autoreload
# %autoreload 2
import os, sys
for path in ('../py', '../smanmi/py'):
    if path not in sys.path:
        sys.path.append(path)
# !pwd  # Should be notebook directory!
# Out:
# /Users/ast/git/nuru/notebooks

# %%
import numpy as np
from smanmi import signals as S

# %%
S.To(0, 5)(value=0)
# Out:
# 0.0
